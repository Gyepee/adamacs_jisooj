# %%
import os
# change to the upper level folder to detect dj_local_conf.json
if os.path.basename(os.getcwd())=='notebooks': os.chdir('..')
assert os.path.basename(os.getcwd())=='adamacs', ("Please move to the main directory")
from adamacs.pipeline import subject, session, equipment, surgery, event, trial, imaging, behavior, scan
from adamacs.ingest import session as isess
from adamacs.helpers import stack_helpers as sh
from adamacs.ingest import behavior as ibe
import datajoint as dj
from rspace_client.eln import eln
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dj.__version__
# Out:
# [2023-08-01 08:29:26,946][INFO]: Connecting tobiasr@172.26.128.53:3306
# [2023-08-01 08:29:26,992][INFO]: Connected tobiasr@172.26.128.53:3306
# '0.14.1'

# %% [markdown]
# # Recordings for BonnBrain

# %% [markdown]
# # Delete individual scans, sessinos or mice

# %%
# (session.Session & "session_id = 'sess9FI3KWP3'").delete()
# (subject.Subject & "subject = 'ROS-1571'").delete()
# # subject.Subject.delete()
# # session.Session.delete()
# # imaging.Processing.delete()
# # imaging.Curation.delete()
# # event.Event.delete()
# # event.BehaviorRecording.delete()

# %% [markdown]
# # Manual ingest of specifc recordings

# %%
# scansi = "scan9FJ4IJOQ"
scansi = "scan9FHF1JT7"
scan_key = (scan.Scan & f'scan_id = "{scansi}"').fetch('KEY')[0]
sessi = (scan.Scan & f'scan_id = "{scansi}"').fetch('session_id')[0]
aux_setup_typestr = (scan.ScanInfo() & scan_key).fetch("userfunction_info")[0]


session.SessionUser() * subject.User() & scan_key
# Out:
# *session_id    *user_id    name           shorthand     initials     email          lab
# +------------+ +---------+ +------------+ +-----------+ +----------+ +------------+ +------+
# sess9FHF1JT7   3           Krasilshchikov nataliak      NK            nkra1@uni-bon Rose
#  (Total: 1)

# %%
aux_setup_typestr = (scan.ScanInfo() & scan_key).fetch("userfunction_info")[0]  
aux_setup_typestr
# Out:
# 'openfield'

# %%
ibe.ingest_aux(sessi,scansi,verbose=True, aux_setup_type=aux_setup_typestr)
# Out:
# Number of aux-files found: 1
# [PosixPath('/datajoint-data/data/tobiasr/NK_ROS-1485_2023-04-06_scan9FHF1JT7_sess9FHF1JT7')]
# /home/tobiasr/miniconda3/envs/datajoint/lib/python3.8/site-packages/pywavesurfer/ws.py:46: RuntimeWarning: You are reading a WaveSurfer file version this module was not tested with: file version 1.0.6, latest version tested: 0.982
#   warnings.warn('You are reading a WaveSurfer file version this module was not tested with: '

# %%
event.Event() & scan_key
# Out:
# *session_id    *scan_id       *event_type    *event_start_t event_end_time
# +------------+ +------------+ +------------+ +------------+ +------------+
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      4.80005        5.79995
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      8.3            9.09995
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      12.2           13.2
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      17.6           19.1999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      20.3           20.7999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      22.0           22.5
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      25.6           26.5
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      30.2           32.0999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      33.1           35.0999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      37.6           38.2
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      39.4           39.7
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      42.4           42.7999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      46.6           47.7999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      51.2           51.7
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      56.5           57.5999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      62.0           62.2999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      65.4           67.1
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      68.4           69.2999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      72.9           73.8999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      76.6           77.3999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      81.2           82.7
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      87.4           88.6
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      92.7           94.4999
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      96.5           98.1
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      99.2           100.9
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      104.9          106.4
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      108.7          109.6
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      113.1          115.0
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      119.1          120.4
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      125.4          126.2
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      128.6          129.8
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      131.8          132.8
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      137.8          138.7
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      142.6          143.2
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      147.2          147.5
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      151.1          152.1
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      153.3          154.3
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      157.8          158.5
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      163.1          163.4
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      165.5          166.1
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      168.8          170.5
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      174.6          175.8
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      178.7          180.1
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      182.0          183.8
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      185.9          186.5
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      188.9          190.4
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      192.0          192.7
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      195.6          196.5
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      201.1          201.4
# sess9FHF1JT7   scan9FHF1JT7   arena_LED      206.1          207.1
#    ...
#  (Total: 55816)

# %%
ibe.get_and_ingest_trial_times(scansi, aux_setup_typestr)

# %%
# (event.BehaviorRecording() & scan_key).delete()
(event.BehaviorRecording() & scan_key)
# Out:
# *session_id    *scan_id       recording_star recording_dura recording_note
# +------------+ +------------+ +------------+ +------------+ +------------+
# sess9FHF1JT7   scan9FHF1JT7   2023-04-06 09: 620.0
#  (Total: 1)

# %%
scan.ScanPath &  scan_key
# Out:
# *session_id    *scan_id       *user_id    *path
# +------------+ +------------+ +---------+ +------------+
# sess9FHF1JT7   scan9FHF1JT7   3           /datajoint-dat
#  (Total: 1)

# %%
behavior.HarpRecording.populate()
# Out:
# Failed to ingest HARP IMU data for {'session_id': 'sess9FB2LN5C', 'scan_id': 'scan9FB2LN5C', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FGK8ZKS', 'scan_id': 'scan9FGK8ZKS', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FGLE1FN', 'scan_id': 'scan9FGLE1FN', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FGLEFJ3', 'scan_id': 'scan9FGLEFJ3', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FGT7SQ0', 'scan_id': 'scan9FGT7SQ0', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FGT7SQ0', 'scan_id': 'scan9FGT7ZLH', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FGTSPEH', 'scan_id': 'scan9FGTSPEH', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FH37WBZ', 'scan_id': 'scan9FH37WBZ', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHBNX7F', 'scan_id': 'scan9FHBNX7F', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHDA7AI', 'scan_id': 'scan9FHDA7AI', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHDA7AI', 'scan_id': 'scan9FHDADB9', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHELAYA', 'scan_id': 'scan9FHELAYA', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHELAYA', 'scan_id': 'scan9FHELMRY', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHELAYA', 'scan_id': 'scan9FHELX2S', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHELAYA', 'scan_id': 'scan9FHEMBE2', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHF1JT7', 'scan_id': 'scan9FHF1JT7', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHF1JT7', 'scan_id': 'scan9FHF1SXZ', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHF1JT7', 'scan_id': 'scan9FHF202P', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHF2GDD', 'scan_id': 'scan9FHF2GDD', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHIRPBE', 'scan_id': 'scan9FHIRPBE', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FHS7Y22', 'scan_id': 'scan9FHS845A', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FI8CMBR', 'scan_id': 'scan9FI8CMBR', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FI8D69V', 'scan_id': 'scan9FI8D69V', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FI8DENL', 'scan_id': 'scan9FI8DENL', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FI8DMKY', 'scan_id': 'scan9FI8DMKY', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FI8DUMJ', 'scan_id': 'scan9FI8DUMJ', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FI8DYIV', 'scan_id': 'scan9FI8DYIV', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FI8EG86', 'scan_id': 'scan9FI8EG86', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FI8EP0T', 'scan_id': 'scan9FI8EP0T', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FI8ETDQ', 'scan_id': 'scan9FI8ETDQ', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FIBT7CK', 'scan_id': 'scan9FIBT7CK', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FIBTDD0', 'scan_id': 'scan9FIBTDD0', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FIBTYBC', 'scan_id': 'scan9FIBTYBC', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FIBUH7F', 'scan_id': 'scan9FIBUH7F', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FIZNWNS', 'scan_id': 'scan9FIZNWNS', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ22934', 'scan_id': 'scan9FJ22934', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ4IJK9', 'scan_id': 'scan9FJ4IJK9', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ4IJOQ', 'scan_id': 'scan9FJ4IJOQ', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ5KHBX', 'scan_id': 'scan9FJ5KHBX', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ5L18B', 'scan_id': 'scan9FJ5L18B', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ5L9VD', 'scan_id': 'scan9FJ5L9VD', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ5LHYE', 'scan_id': 'scan9FJ5LHYE', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ5LVCL', 'scan_id': 'scan9FJ5LVCL', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ5LZ1C', 'scan_id': 'scan9FJ5LZ1C', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ5MGQ9', 'scan_id': 'scan9FJ5MGQ9', 'harp_device_id': 1}
# Failed to ingest HARP IMU data for {'session_id': 'sess9FJ5MPW6', 'scan_id': 'scan9FJ5MPW6', 'harp_device_id': 1}

# %%
aux_setup_typestr = (scan.ScanInfo() & 'scan_id = "' + scansi + '"').fetch("userfunction_info")[0]  



ibe.get_and_ingest_trial_times(scansi, aux_setup_typestr) 

behavior.TreadmillRecording.populate()
behavior.HarpRecording.populate()

key = {'session_id': scan_key["session_id"],
                                'recording_id': scan_key["scan_id"], 
                                'camera': "mini2p1_top", # Currently 'scanner' due to in equipment tables
                                }
                                
imaging.Processing.populate(**populate_settings)
imaging.Curation().create1_from_processing_task({'session_id': sessi, 'scan_id': scansi, "paramset_idx": selected_s2pparms_index[i], "manual_curation": session_checkboxes[i][1].value})
imaging.MotionCorrection.populate(**populate_settings)

                        imaging.Segmentation.populate(**populate_settings)

                        imaging.MaskClassification.populate(**populate_settings)

                        imaging.Fluorescence.populate(**populate_settings)

                        imaging.Activity.populate(**populate_settings)
